# %%
import pickle
import pandas as pd
import numpy as np

# protocol 4 이하로 강제 읽기
with open('data/LSWMD.pkl', 'rb') as f:
    data = f.read()

import io
df = pd.read_pickle(io.BytesIO(data), compression=None)
print("Shape:", df.shape)
# Out:
# Shape: (811457, 6)

# %%
print(df.shape)
# Out:
# (811457, 6)
